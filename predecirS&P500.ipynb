# %%
import yfinance as yf
sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period="max")
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-05-01 00:00:00-04:00  5029.029785  5096.120117  5013.450195  5018.390137
# 2024-05-02 00:00:00-04:00  5049.319824  5073.209961  5011.049805  5064.200195
# 2024-05-03 00:00:00-04:00  5122.779785  5139.120117  5101.220215  5127.790039
# 2024-05-06 00:00:00-04:00  5142.419922  5181.000000  5142.419922  5180.740234
# 2024-05-07 00:00:00-04:00  5187.200195  5200.229980  5178.959961  5187.700195
#
# ...

# %%
sp500 = sp500.drop(["Dividends", "Stock Splits"], axis = 1)
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-05-01 00:00:00-04:00  5029.029785  5096.120117  5013.450195  5018.390137
# 2024-05-02 00:00:00-04:00  5049.319824  5073.209961  5011.049805  5064.200195
# 2024-05-03 00:00:00-04:00  5122.779785  5139.120117  5101.220215  5127.790039
# 2024-05-06 00:00:00-04:00  5142.419922  5181.000000  5142.419922  5180.740234
# 2024-05-07 00:00:00-04:00  5187.200195  5200.229980  5178.959961  5187.700195
#
# ...

# %%
sp500["Precio mañana"] = sp500["Close"].shift(-1)
sp500["Alza"] = (sp500["Precio mañana"] > sp500["Close"]).astype(int)
sp500 = sp500.loc["2014-01-01":].copy()
sp500 = sp500.dropna()
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2014-01-02 00:00:00-05:00  1845.859985  1845.859985  1827.739990  1831.979980
# 2014-01-03 00:00:00-05:00  1833.209961  1838.239990  1829.130005  1831.369995
# 2014-01-06 00:00:00-05:00  1832.310059  1837.160034  1823.729980  1826.770020
# 2014-01-07 00:00:00-05:00  1828.709961  1840.099976  1828.709961  1837.880005
# 2014-01-08 00:00:00-05:00  1837.900024  1840.020020  1831.400024  1837.489990
# ...                                ...          ...          ...          ...
# 2024-04-30 00:00:00-04:00  5103.779785  5110.830078  5035.310059  5035.689941
# 2024-05-01 00:00:00-04:00  5029.029785  5096.120117  5013.450195  5018.390137
# 2024-05-02 00:00:00-04:00  5049.319824  5073.209961  5011.049805  5064.200195
# 2024-05-03 00:00:00-04:00  5122.779785  5139.120117  5101.220215  5127.790039
# 2024-05-06 00:00:00-04:00  5142.419922  5181.000000  5142.419922  5180.740234
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

model = RandomForestClassifier(n_estimators=500, min_samples_split=250, random_state=1, max_depth=3, criterion="entropy")

X = sp500[[ "Open", "High", "Low", "Close", "Volume" ]]
y = sp500[['Alza']].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42, shuffle=True)
model.fit(X_train, y_train)
preds = model.predict(X_test)
precision = precision_score(y_test, preds)
print("Precisión:", precision)
# Out:
# Precisión: 0.5620347394540943
